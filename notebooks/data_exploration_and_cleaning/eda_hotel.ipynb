# %%
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Memuat variabel lingkungan dari file .env
load_dotenv()

# Mengakses variabel lingkungan yang diatur dalam file .env
project_path = os.getenv("PROJECT_FOLDER")
dataset_folder = 'data/raw_data/trip_advisor'

# %%
# List of dataset files
files = [
    f"{project_path}/{dataset_folder}/json/balikpapan_hotels.json",
    f"{project_path}/{dataset_folder}/json/berau_hotels.json",
    f"{project_path}/{dataset_folder}/json/bontang_hotels.json",
    f"{project_path}/{dataset_folder}/json/kutai_hotels.json",
    f"{project_path}/{dataset_folder}/json/paser_hotels.json",
    f"{project_path}/{dataset_folder}/json/penajam_hotels.json",
    f"{project_path}/{dataset_folder}/json/samarinda_hotels.json",
]

# Read and concatenate all datasets into a single DataFrame
dfs = []
for file in files:
    with open(file, encoding='utf-8') as json_file:
        data = json.load(json_file)
        df = pd.DataFrame(data)
        dfs.append(df)

df = pd.concat(dfs)

# %%
df.shape
# Out:
# (251, 27)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 251 entries, 0 to 85
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     251 non-null    object
#  1   type                   251 non-null    object
#  2   name                   251 non-null    object
#  3   image                  161 non-null    object
#  4   awards                 251 non-null    object
#  5   rankingPosition        112 non-null    object
#  6   priceLevel             135 non-null    object
#  7   priceRange             136 non-null    object
#  8   category               251 non-null    object
#  9   rating                 112 non-null    float64
#  10  hotelClass             251 non-null    object
#  11  hotelClassAttribution  86 non-null     object
#  12  phone                  125 non-null    object
#  13  address                251 non-null    object
#  14  email                  94 non-null     object
#  15  amenities              251 non-null    object
#  16  numberOfRooms          132 non-null    float64
#  17  prices                 251 non-null    object
#  18  latitude               232 non-null    object
#  19  longitude              232 non-null    object
#  20  webUrl                 251 non-null    object
#  21  website                165 non-null    object
#  22  rankingString          112 non-null    object
#  23  rankingDenominator     112 non-null    object
#  24  numberOfReviews        251 non-null    int64
#  25  reviews                251 non-null    object
#  26  reviewTags             251 non-null    object
# dtypes: float64(2), int64(1), object(24)
# memory usage: 54.9+ KB

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#          id   type                          name  \
# 0   3853695  HOTEL         favehotel MT. Haryono
# 1   1953153  HOTEL  Grand Jatra Hotel Balikpapan
# 2   1746523  HOTEL     Blue Sky Hotel Balikpapan
# 3  11911745  HOTEL         Hotel Neo+ Balikpapan
# 4    634383  HOTEL            Novotel Balikpapan
#
#                                                image awards rankingPosition  \
# 0  https://media-cdn.tripadvisor.com/media/photo-...     []               5
# 1  https://media-cdn.tripadvisor.com/media/photo-...     []               7
# 2  https://media-cdn.tripadvisor.com/media/photo-...     []               3
# 3  https://media-cdn.tripadvisor.com/media/photo-...     []               9
# 4  https://media-cdn.tripadvisor.com/media/photo-...     []               6
#
#   priceLevel priceRange category  rating hotelClass  \
# 0          $  $28 - $30    hotel     4.0        0.0
# 1          $  $61 - $75    hotel     4.0        4.0
# 2          $  $38 - $46    hotel     4.0        4.0
# 3          $  $32 - $39    hotel     4.0        3.0
# 4          $  $45 - $51    hotel     3.5        5.0
#
#                                hotelClassAttribution            phone  \
# 0                                               None  +62 542 7585999
# 1    This property is classified according to Giata.  +62 542 7213888
# 2    This property is classified according to Giata.   01162542735845
# 3    This property is classified according to Giata.  +62 542 8515000
# 4  This property is classified according to Accor...   +62 542 733111
#
#                                              address  \
# 0  Jl. MT. Haryono no. 78 Daerah DAM, Belakang Ha...
# 1  Jl. Jenderal Sudirman no. 47 Balikpapan Superb...
# 2  Jl. Letjen Suprapto No. 1, Balikpapan 76113 In...
# 3  Jl. Mayjen Sutoyo no. 67, Balikpapan 76122 Ind...
# 4  Jl. Brigjen Eri Suparjan no. 2, Balikpapan 761...
#
#                                   email amenities  numberOfRooms prices  \
# 0         Balikpapaninfo@favehotels.com        []          112.0     []
# 1  reservation@jatrahotelbalikpapan.com        []          215.0     []
# 2                info@blueskygroups.com        []          170.0     []
# 3          balikpapaninfo@neohotels.com        []          101.0     []
# 4     reservation@novotelbalikpapan.com        []          198.0     []
#
#     latitude  longitude                                             webUrl  \
# 0  -1.266061  116.85731  https://www.tripadvisor.com/Hotel_Review-g3171...
# 1  -1.273157   116.8594  https://www.tripadvisor.com/Hotel_Review-g3171...
# 2  -1.240827  116.82818  https://www.tripadvisor.com/Hotel_Review-g3171...
# 3  -1.262808  116.84035  https://www.tripadvisor.com/Hotel_Review-g3171...
# 4  -1.275863  116.83478  https://www.tripadvisor.com/Hotel_Review-g3171...
#
#                                              website  \
# 0  https://www.favehotels.com/en/hotel/view/38/fa...
# 1  http://www.jatrahotels.com/grandjatra-balikpapan/
# 2                        https://www.blue-sky.co.id/
# 3  http://www.neohotels.com/en/location/overview/...
# 4  http://www.accorhotels.com/gb/hotel-6445-novot...
#
#                     rankingString rankingDenominator  numberOfReviews  \
# 0  #5 of 122 hotels in Balikpapan                122              351
# 1  #7 of 122 hotels in Balikpapan                122              416
# 2  #3 of 122 hotels in Balikpapan                122              221
# 3  #9 of 122 hotels in Balikpapan                122              102
# 4  #6 of 122 hotels in Balikpapan                122              633
#
#                                              reviews  \
# 0  [{'id': '762363404', 'lang': 'en', 'location_i...
# 1  [{'id': '887821772', 'lang': 'en', 'location_i...
# 2  [{'id': '875924587', 'lang': 'en', 'location_i...
# 3  [{'id': '883862513', 'lang': 'en', 'location_i...
# 4  [{'id': '887891858', 'lang': 'en', 'location_i...
#
#                                           reviewTags
# 0                                                 []
# 1  [{'text': 'location is great', 'review_count':...
# 2  [{'text': 'mantau', 'review_count': 10}, {'tex...
# 3  [{'text': 'clean hotel', 'review_count': 3}, {...
# 4  [{'text': 'business meeting', 'review_count': ...

# %%
# Create a new dataframe with selected columns
new_df = df[['id', 'name','rating', 'hotelClass', 'address', 'latitude', 'longitude', 'phone', 'numberOfRooms', 'website','image']]

# %%
# Rename the columns to match the desired names
new_df.columns = ['original_id', 'hotel_name','rating', 'hotel_class', 'address', 'latitude', 'longitude', 'contact_number', 'number_of_rooms', 'website','image']

# %%
# Extract the city from the address column
new_df['city'] = new_df['address'].apply(lambda x: x.split(',')[-1].strip() if not x.split(',')[-1].strip().isdigit() else x.split(',')[-2].strip())
new_df['city'] = new_df['city'].apply(lambda x: x.split(' ')[0])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5852\4187621672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['city'] = new_df['address'].apply(lambda x: x.split(',')[-1].strip() if not x.split(',')[-1].strip().isdigit() else x.split(',')[-2].strip())
# C:\Users\HP\AppData\Local\Temp\ipykernel_5852\4187621672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['city'] = new_df['city'].apply(lambda x: x.split(' ')[0])

# %%
# Set min_price and max_price columns to 0
new_df['min_price'] = 0
new_df['max_price'] = 0
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5852\1635972983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['min_price'] = 0
# C:\Users\HP\AppData\Local\Temp\ipykernel_5852\1635972983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['max_price'] = 0

# %%
# Display the new dataframe
new_df.head()
# Out:
#   original_id                    hotel_name  rating hotel_class  \
# 0     3853695         favehotel MT. Haryono     4.0         0.0
# 1     1953153  Grand Jatra Hotel Balikpapan     4.0         4.0
# 2     1746523     Blue Sky Hotel Balikpapan     4.0         4.0
# 3    11911745         Hotel Neo+ Balikpapan     4.0         3.0
# 4      634383            Novotel Balikpapan     3.5         5.0
#
#                                              address   latitude  longitude  \
# 0  Jl. MT. Haryono no. 78 Daerah DAM, Belakang Ha...  -1.266061  116.85731
# 1  Jl. Jenderal Sudirman no. 47 Balikpapan Superb...  -1.273157   116.8594
# 2  Jl. Letjen Suprapto No. 1, Balikpapan 76113 In...  -1.240827  116.82818
# 3  Jl. Mayjen Sutoyo no. 67, Balikpapan 76122 Ind...  -1.262808  116.84035
# 4  Jl. Brigjen Eri Suparjan no. 2, Balikpapan 761...  -1.275863  116.83478
#
#     contact_number  number_of_rooms  \
# 0  +62 542 7585999            112.0
# 1  +62 542 7213888            215.0
# 2   01162542735845            170.0
# 3  +62 542 8515000            101.0
# 4   +62 542 733111            198.0
#
#                                              website  \
# 0  https://www.favehotels.com/en/hotel/view/38/fa...
# 1  http://www.jatrahotels.com/grandjatra-balikpapan/
# 2                        https://www.blue-sky.co.id/
# 3  http://www.neohotels.com/en/location/overview/...
# 4  http://www.accorhotels.com/gb/hotel-6445-novot...
#
#                                                image        city  min_price  \
# 0  https://media-cdn.tripadvisor.com/media/photo-...  Balikpapan          0
# 1  https://media-cdn.tripadvisor.com/media/photo-...  Balikpapan          0
# 2  https://media-cdn.tripadvisor.com/media/photo-...  Balikpapan          0
# 3  https://media-cdn.tripadvisor.com/media/photo-...  Balikpapan          0
# 4  https://media-cdn.tripadvisor.com/media/photo-...  Balikpapan          0
#
#    max_price
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Reset the index of the new dataframe
new_df.reset_index(drop=True, inplace=True)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   original_id      251 non-null    object
#  1   hotel_name       251 non-null    object
#  2   rating           112 non-null    float64
#  3   hotel_class      251 non-null    object
#  4   address          251 non-null    object
#  5   latitude         232 non-null    object
#  6   longitude        232 non-null    object
#  7   contact_number   125 non-null    object
#  8   number_of_rooms  132 non-null    float64
#  9   website          165 non-null    object
#  10  image            161 non-null    object
#  11  city             251 non-null    object
#  12  min_price        251 non-null    int64
#  13  max_price        251 non-null    int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 27.6+ KB

# %%
# Drop rows with null values in latitude or longitude columns
new_df = new_df.dropna(subset=['latitude', 'longitude'])

# %%
# Calculate the average rating
average_rating = new_df['rating'].mean()

# Replace null values with the average rating
new_df['rating'].fillna(average_rating, inplace=True)

# %%
# Calculate the average number of rooms
average_number_of_rooms = new_df['number_of_rooms'].mean()

# Round the average number of rooms and convert it to float
average_number_of_rooms = round(average_number_of_rooms)
average_number_of_rooms = float(average_number_of_rooms)

# Replace null values with the average number of rooms
new_df['number_of_rooms'].fillna(average_number_of_rooms, inplace=True)

# %%
# Update values in the 'city' column
new_df.loc[new_df['city'] == 'Tanah', 'city'] = 'Penajam'
new_df.loc[new_df['city'] == 'Kutai', 'city'] = 'Kutai Kertanegara'

# %%
# Print the unique categories in the 'city' column
categories = new_df['city'].unique()
print(categories)
# Out:
# ['Balikpapan' 'Berau' 'Bontang' 'Kutai Kertanegara' 'Penajam' 'Samarinda']

# %%
new_df.describe()
# Out:
#            rating  number_of_rooms  min_price  max_price
# count  232.000000       232.000000      232.0      232.0
# mean     3.604762        72.939655        0.0        0.0
# std      0.525734        46.520635        0.0        0.0
# min      2.000000         5.000000        0.0        0.0
# 25%      3.500000        45.000000        0.0        0.0
# 50%      3.604762        73.000000        0.0        0.0
# 75%      3.604762        73.000000        0.0        0.0
# max      5.000000       300.000000        0.0        0.0

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 232 entries, 0 to 250
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   original_id      232 non-null    object
#  1   hotel_name       232 non-null    object
#  2   rating           232 non-null    float64
#  3   hotel_class      232 non-null    object
#  4   address          232 non-null    object
#  5   latitude         232 non-null    object
#  6   longitude        232 non-null    object
#  7   contact_number   115 non-null    object
#  8   number_of_rooms  232 non-null    float64
#  9   website          158 non-null    object
#  10  image            155 non-null    object
#  11  city             232 non-null    object
#  12  min_price        232 non-null    int64
#  13  max_price        232 non-null    int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 35.3+ KB

# %%
new_df.to_json(f"{project_path}/data/processed_data/json/hotel.json", orient='records')
